# %%
import numpy as np
with open('public/ganzilla_images/raw_images/0_0/0/0/' + 'directions_list.npy', 'rb') as f:
            directions_list = np.load(f)

# %%
directions_list.shape
# Out:
# (10, 1319)

# %%
import pickle
directions = pickle.load( open('public/ganzilla_images/raw_images/0_0/0/0/' + 'directions.pkl', "rb" ) )

# %%
directions[1]
# Out:
# [(None, tensor([[5.4661]], device='cuda:0', requires_grad=True)),
#  (tensor([[ 1.8882,  2.2296,  1.0014,  1.4442,  1.6535, -3.1590, -0.5370, -3.9114,
#            -0.1406, -0.3800,  2.4073,  1.6623,  1.6699,  0.5042,  3.0143,  2.3013,
#             0.8822,  4.2007,  2.5440,  5.0593, -4.0386, -3.7204,  4.5752,  0.2441,
#             2.1540,  3.6153,  4.2794,  1.8143, -1.9866,  2.4523, -3.3366, -3.0619,
#            -0.6891, -2.9961,  2.6807, -0.5458, -1.4051,  1.6774,  7.4538,  2.6209,
#            -0.2668,  2.8764]], device='cuda:0', requires_grad=True),
#   tensor([[ 5.5649,  5.7651, -4.0698,  4.1585,  2.6677,  7.4346,  2.2696, -2.2079,
#            -2.8527,  6.0490, -5.0923, -1.0442,  0.0794,  6.3667, -0.3362,  3.2332,
#            -0.2139,  2.8403,  7.0617,  4.2597,  5.7536,  1.8319,  6.3699]],
#          device='cuda:0', requires_grad=True)),
#  (tensor([[ 4.4072, -1.2619,  0.0338,  3.4966,  4.6324,  4.4872,  2.4424,  7.1800,
# ...
